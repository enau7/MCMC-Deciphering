# %%
# %run run_deciphering.py -i data/warpeace_input.txt -d data/student_scrambled/11_scramble.txt
# Out:
# --------------------------------------------------------------------------------
#
#  Entropy :  -4753.5661 , Iteration :  1 , Acceptance Probability :  1.0
# --------------------------------------------------------------------------------
#
# eAx Ivjpwx Anw zxxu n hvvM snIx wv Cnp, nuM RAx axIRjpxw nuM svwRxM JnRxpEnaw npx cxpf AxasCja. GvFxcxp, q zxaExcx RAnR EuIajMEuh RAx nuwFxpw nuM RAx pxaxcnuR Fvpy jwxM Rv nuwFxp RAx DjxwREvuw nwyxM vu RAx axIRjpx waEMxw FvjaM zx Jvpx AxasCja FAxu q nJ pxcExFEuh RAx waEMxw Cvp AvJxFvpy nuM xTnJw. qR FvjaM Axas zxRRxp xTsanEu RAx JnRxpEna nuM nawv Axasw Jx zxRRxp juMxpwRnuM RAx IvuIxsRw.
#
# ...
