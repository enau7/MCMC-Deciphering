# %%
# %run run_deciphering.py -i data/warpeace_input.txt -d data/student_scrambled/11_scramble.txt
# Out:
# --------------------------------------------------------------------------------
#
#  Entropy :  -4700.1936 , Iteration :  1 , Acceptance Probability :  0.5
# --------------------------------------------------------------------------------
#
# eAx Ivjpwx Anw zxxu n hvvM snIx wv Cnp, nuM RAx axIRjpxw nuM svwRxM tnRxpEnaw npx cxpf AxasCja. GvFxcxp, q zxaExcx RAnR EuIajMEuh RAx nuwFxpw nuM RAx pxaxcnuR Fvpy jwxM Rv nuwFxp RAx DjxwREvuw nwyxM vu RAx axIRjpx waEMxw FvjaM zx tvpx AxasCja FAxu q nt pxcExFEuh RAx waEMxw Cvp AvtxFvpy nuM xTntw. qR FvjaM Axas zxRRxp xTsanEu RAx tnRxpEna nuM nawv Axasw tx zxRRxp juMxpwRnuM RAx IvuIxsRw.
#
# ...
